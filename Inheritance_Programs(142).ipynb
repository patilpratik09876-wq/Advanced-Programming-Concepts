# %%
# Program 1: Employee and Manager - Single Inheritance
class Employee:
    def __init__(self, emp_id, name, salary):
        self.emp_id = emp_id
        self.name = name
        self.salary = salary

    def display(self):
        print("ID:", self.emp_id)
        print("Name:", self.name)
        print("Monthly Salary:", self.salary)

class Manager(Employee):
    def __init__(self, emp_id, name, salary, department):
        super().__init__(emp_id, name, salary)
        self.department = department

    def display_manager(self):
        self.display()
        print("Department:", self.department)
        print("Annual Salary:", self.salary * 12)

e = Employee(101, "Amit", 30000)
e.display()
print()
m = Manager(102, "Rahul", 50000, "IT")
m.display_manager()
# Out:
# ID: 101
# Name: Amit
# Monthly Salary: 30000
#
# ID: 102
# Name: Rahul
# Monthly Salary: 50000
# Department: IT
# Annual Salary: 600000

# %%
# Program 2: Vehicle and Car - Single Inheritance
class Vehicle:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def display(self):
        print("Brand:", self.brand)
        print("Model:", self.model)

class Car(Vehicle):
    def __init__(self, brand, model, fuel_type, price):
        super().__init__(brand, model)
        self.fuel_type = fuel_type
        self.price = price

    def details(self):
        self.display()
        print("Fuel Type:", self.fuel_type)
        print("Price:", self.price)

    def discount(self, percent):
        final = self.price - self.price * percent / 100
        print("Discounted Price:", final)

c = Car("Tata", "Nexon", "Petrol", 1000000)
c.details()
c.discount(10)
# Out:
# Brand: Tata
# Model: Nexon
# Fuel Type: Petrol
# Price: 1000000
# Discounted Price: 900000.0

# %%
# Program 3: Academic, Sports and Student - Multiple Inheritance
class Academic:
    def __init__(self, marks):
        self.marks = marks

class Sports:
    def __init__(self, sports_points):
        self.sports_points = sports_points

class Student(Academic, Sports):
    def __init__(self, marks, sports_points):
        Academic.__init__(self, marks)
        Sports.__init__(self, sports_points)

    def performance(self):
        total = self.marks + self.sports_points
        print("Academic Marks:", self.marks)
        print("Sports Points:", self.sports_points)
        print("Overall Performance:", total)

s = Student(80, 15)
s.performance()
# Out:
# Academic Marks: 80
# Sports Points: 15
# Overall Performance: 95

# %%
# Program 4: Personal and Professional Details - Multiple Inheritance
class PersonalDetails:
    def __init__(self, name, age):
        self.name = name
        self.age = age

class ProfessionalDetails:
    def __init__(self, emp_id, designation, salary):
        self.emp_id = emp_id
        self.designation = designation
        self.salary = salary

class Employee(PersonalDetails, ProfessionalDetails):
    def __init__(self, name, age, emp_id, designation, salary):
        PersonalDetails.__init__(self, name, age)
        ProfessionalDetails.__init__(self, emp_id, designation, salary)

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Employee ID:", self.emp_id)
        print("Designation:", self.designation)
        print("Salary:", self.salary)

e = Employee("Amit", 30, 101, "Developer", 40000)
e.display()
# Out:
# Name: Amit
# Age: 30
# Employee ID: 101
# Designation: Developer
# Salary: 40000

# %%
# Program 5: Person, Student and ResearchStudent - Multilevel Inheritance
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

class Student(Person):
    def __init__(self, name, age, roll_no, course):
        super().__init__(name, age)
        self.roll_no = roll_no
        self.course = course

class ResearchStudent(Student):
    def __init__(self, name, age, roll_no, course, topic, guide):
        super().__init__(name, age, roll_no, course)
        self.topic = topic
        self.guide = guide

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Roll No:", self.roll_no)
        print("Course:", self.course)
        print("Research Topic:", self.topic)
        print("Guide:", self.guide)

r = ResearchStudent("Rahul", 24, 10, "CSE", "Artificial Intelligence", "Dr. Patil")
r.display()
# Out:
# Name: Rahul
# Age: 24
# Roll No: 10
# Course: CSE
# Research Topic: Artificial Intelligence
# Guide: Dr. Patil

# %%
# Program 6: Bank Account - Multilevel Inheritance
class BankAccount:
    def __init__(self, account_no, balance):
        self.account_no = account_no
        self.balance = balance

class SavingsAccount(BankAccount):
    def __init__(self, account_no, balance, interest_rate):
        super().__init__(account_no, balance)
        self.interest_rate = interest_rate

    def interest(self):
        return self.balance * self.interest_rate / 100

class PremiumSavingsAccount(SavingsAccount):
    def __init__(self, account_no, balance, interest_rate, benefit):
        super().__init__(account_no, balance, interest_rate)
        self.benefit = benefit

    def display(self):
        print("Account No:", self.account_no)
        print("Balance:", self.balance)
        print("Interest:", self.interest())
        print("Benefit:", self.benefit)

a = PremiumSavingsAccount(12345, 50000, 5, "Free ATM Transactions")
a.display()
# Out:
# Account No: 12345
# Balance: 50000
# Interest: 2500.0
# Benefit: Free ATM Transactions

# %%
# Program 7: Shape Area - Hierarchical Inheritance
class Shape:
    def display(self, name):
        print("Shape:", name)

class Circle(Shape):
    def area(self, radius):
        self.display("Circle")
        print("Area:", 3.14 * radius * radius)

class Rectangle(Shape):
    def area(self, length, breadth):
        self.display("Rectangle")
        print("Area:", length * breadth)

class Triangle(Shape):
    def area(self, base, height):
        self.display("Triangle")
        print("Area:", 0.5 * base * height)

Circle().area(5)
Rectangle().area(10, 5)
Triangle().area(10, 6)
# Out:
# Shape: Circle
# Area: 78.5
# Shape: Rectangle
# Area: 50
# Shape: Triangle
# Area: 30.0

# %%
# Program 8: Employee Salary Allowances - Hierarchical Inheritance
class Employee:
    def __init__(self, emp_id, name, basic):
        self.emp_id = emp_id
        self.name = name
        self.basic = basic

class Manager(Employee):
    def salary(self):
        print("Manager Salary:", self.basic + self.basic * 0.30)

class Developer(Employee):
    def salary(self):
        print("Developer Salary:", self.basic + self.basic * 0.20)

class Tester(Employee):
    def salary(self):
        print("Tester Salary:", self.basic + self.basic * 0.15)

Manager(1, "Amit", 50000).salary()
Developer(2, "Rahul", 40000).salary()
Tester(3, "Neha", 35000).salary()
# Out:
# Manager Salary: 65000.0
# Developer Salary: 48000.0
# Tester Salary: 40250.0

# %%
# Program 9: Teaching Assistant - Multiple and Hierarchical Inheritance
class Person:
    def __init__(self, name):
        self.name = name

class Student(Person):
    def __init__(self, name, roll_no):
        Person.__init__(self, name)
        self.roll_no = roll_no

class Faculty(Person):
    def __init__(self, name, subject):
        Person.__init__(self, name)
        self.subject = subject

class TeachingAssistant(Student, Faculty):
    def __init__(self, name, roll_no, subject):
        Student.__init__(self, name, roll_no)
        Faculty.__init__(self, name, subject)

    def display(self):
        print("Name:", self.name)
        print("Roll No:", self.roll_no)
        print("Subject:", self.subject)

ta = TeachingAssistant("Rahul", 20, "Python")
ta.display()
# Out:
# Name: Rahul
# Roll No: 20
# Subject: Python

# %%
# Program 10: Vehicle, Car, Bike, SportsCar and ElectricBike - Hybrid Inheritance
class Vehicle:
    def __init__(self, brand):
        self.brand = brand

class Car(Vehicle):
    def __init__(self, brand, seats):
        super().__init__(brand)
        self.seats = seats

class Bike(Vehicle):
    def __init__(self, brand, mileage):
        super().__init__(brand)
        self.mileage = mileage

class SportsCar(Car):
    def display(self):
        print("Sports Car:", self.brand)
        print("Seats:", self.seats)

class ElectricBike(Bike):
    def display(self):
        print("Electric Bike:", self.brand)
        print("Mileage:", self.mileage)

SportsCar("Ferrari", 2).display()
ElectricBike("Ola", 120).display()
# Out:
# Sports Car: Ferrari
# Seats: 2
# Electric Bike: Ola
# Mileage: 120

# %%
# Program 11: Student Result - Single Inheritance
class Student:
    def __init__(self, roll_no, name, course):
        self.roll_no = roll_no
        self.name = name
        self.course = course

class Result(Student):
    def __init__(self, roll_no, name, course, m1, m2, m3):
        super().__init__(roll_no, name, course)
        self.marks = [m1, m2, m3]

    def calculate(self):
        total = sum(self.marks)
        percentage = total / 3
        if percentage >= 75:
            grade = "A"
        elif percentage >= 60:
            grade = "B"
        elif percentage >= 40:
            grade = "C"
        else:
            grade = "Fail"
        print("Name:", self.name)
        print("Total:", total)
        print("Percentage:", percentage)
        print("Grade:", grade)

r = Result(1, "Rahul", "CSE", 80, 75, 90)
r.calculate()
# Out:
# Name: Rahul
# Total: 245
# Percentage: 81.66666666666667
# Grade: A

# %%
# Program 12: Product and ElectronicProduct - Single Inheritance
class Product:
    def __init__(self, product_id, name, price):
        self.product_id = product_id
        self.name = name
        self.price = price

class ElectronicProduct(Product):
    def __init__(self, product_id, name, price, brand, warranty):
        super().__init__(product_id, name, price)
        self.brand = brand
        self.warranty = warranty

    def final_price(self, discount):
        final = self.price - self.price * discount / 100
        print("Product:", self.name)
        print("Brand:", self.brand)
        print("Warranty:", self.warranty)
        print("Final Price:", final)

p = ElectronicProduct(101, "Laptop", 60000, "Acer", "1 Year")
p.final_price(10)
# Out:
# Product: Laptop
# Brand: Acer
# Warranty: 1 Year
# Final Price: 54000.0

# %%
# Program 13: Multifunction Device - Multiple Inheritance
class Printer:
    def print_document(self):
        print("Document is printing")

class Scanner:
    def scan_document(self):
        print("Document is scanning")

class MultifunctionDevice(Printer, Scanner):
    pass

m = MultifunctionDevice()
m.print_document()
m.scan_document()
# Out:
# Document is printing
# Document is scanning

# %%
# Program 14: Smartphone - Multiple Inheritance
class Camera:
    def take_photo(self):
        print("Photo captured")

class Phone:
    def make_call(self):
        print("Calling...")

class Smartphone(Camera, Phone):
    def display(self):
        print("Smartphone supports Camera and Phone")

s = Smartphone()
s.display()
s.take_photo()
s.make_call()
# Out:
# Smartphone supports Camera and Phone
# Photo captured
# Calling...

# %%
# Program 15: Person to ResearchStudent - Multilevel Inheritance
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

class Student(Person):
    def __init__(self, name, age, roll_no, course):
        super().__init__(name, age)
        self.roll_no = roll_no
        self.course = course

class ResearchStudent(Student):
    def __init__(self, name, age, roll_no, course, topic, guide):
        super().__init__(name, age, roll_no, course)
        self.topic = topic
        self.guide = guide

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Roll No:", self.roll_no)
        print("Course:", self.course)
        print("Topic:", self.topic)
        print("Guide:", self.guide)

r = ResearchStudent("Amit", 23, 12, "CSE", "Machine Learning", "Dr. Shah")
r.display()
# Out:
# Name: Amit
# Age: 23
# Roll No: 12
# Course: CSE
# Topic: Machine Learning
# Guide: Dr. Shah

# %%
# Program 16: Person to ResearchStudent - Multilevel Inheritance (Repeated Question)
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

class Student(Person):
    def __init__(self, name, age, roll_no, course):
        super().__init__(name, age)
        self.roll_no = roll_no
        self.course = course

class ResearchStudent(Student):
    def __init__(self, name, age, roll_no, course, topic, guide):
        super().__init__(name, age, roll_no, course)
        self.topic = topic
        self.guide = guide

    def display(self):
        print(self.name, self.age, self.roll_no, self.course, self.topic, self.guide)

r = ResearchStudent("Rahul", 24, 15, "CSE", "Cloud Computing", "Dr. Patil")
r.display()
# Out:
# Rahul 24 15 CSE Cloud Computing Dr. Patil

# %%
# Program 17: Animal - Hierarchical Inheritance
class Animal:
    def __init__(self, name):
        self.name = name

    def eat(self):
        print(self.name, "is eating")

class Dog(Animal):
    def sound(self):
        print("Dog says Woof")

class Cat(Animal):
    def sound(self):
        print("Cat says Meow")

class Cow(Animal):
    def sound(self):
        print("Cow says Moo")

d = Dog("Tommy")
d.eat()
d.sound()

c = Cat("Kitty")
c.eat()
c.sound()

cow = Cow("Gauri")
cow.eat()
cow.sound()
# Out:
# Tommy is eating
# Dog says Woof
# Kitty is eating
# Cat says Meow
# Gauri is eating
# Cow says Moo

# %%
# Program 18: Medical Hierarchy - Multiple and Hierarchical Inheritance
class Person:
    def __init__(self, name):
        self.name = name

class Doctor(Person):
    def treat(self):
        print(self.name, "treats patients")

class Patient(Person):
    def patient_info(self):
        print(self.name, "is a patient")

class Surgeon(Doctor):
    def surgery(self):
        print(self.name, "performs surgery")

class MedicalResearcher(Doctor, Patient):
    def research(self):
        print(self.name, "does medical research")

s = Surgeon("Dr. Amit")
s.treat()
s.surgery()

m = MedicalResearcher("Dr. Rahul")
m.treat()
m.patient_info()
m.research()
# Out:
# Dr. Amit treats patients
# Dr. Amit performs surgery
# Dr. Rahul treats patients
# Dr. Rahul is a patient
# Dr. Rahul does medical research
